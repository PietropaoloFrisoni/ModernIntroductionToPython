# %% [markdown]
# # Intermezzo 0: Practical Environment

# %%
2+2
# Out:
# 4

# %% [markdown]
# # This is a heading
#
# This is a paragraph of text
#
# $$ E = mc^2 $$

# %%
x = 10

# %%
x + 5
# Out:
# 15

# %%
print("Hello, welcome to this course!")
# Out:
# Hello, welcome to this course!

# %%
"This string will NOT be displayed"
"This string will be displayed"
# Out:
# 'This string will be displayed'

# %%
name = "Pietro"
age = 31
print(f"My name is {name} and I am {age} years old.")
# Out:
# My name is Pietro and I am 31 years old.
